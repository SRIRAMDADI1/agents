# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If three houses are built in a row, each painted a different color (red, blue, and green), and each inhabited by a person of a different nationality (American, British, and Canadian), who own different pets (dog, cat, and bird), and drink different beverages (tea, coffee, and milk), given the following clues:
#
# 1. The American lives in the red house.
# 2. The British drinks tea.
# 3. The Canadian owns the dog.
# 4. The green house is immediately to the right of the red house.
# 5. The occupant of the green house drinks coffee.
# 6. The person who owns the cat lives next to the blue house.
#
# Who owns the bird?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step-by-step with all the given clues.
#
# ### Entities:
#
# - **Houses:** 3 houses in a row (positions 1, 2, 3)
# - **Colors:** red, blue, green (all different)
# - **Nationalities:** American, British, Canadian (all different)
# - **Pets:** dog, cat, bird (all different)
# - **Drinks:** tea, coffee, milk (all different)
#
# ### Clues:
#
# 1. The American lives in the **red** house.
# 2. The British drinks **tea**.
# 3. The Canadian owns the **dog**.
# 4. The **green** house is immediately to the right of the **red** house.
# 5. The occupant of the **green** house drinks **coffee**.
# 6. The person who owns the **cat** lives next to the **blue** house.
#
# ---
#
# ### Step 1: Setup
#
# Label the houses 1, 2, and 3 from left to right.
#
# We know:
#
# - Green is immediately to the right of red. So if red is in position `x`, green must be in position `x+1`.
# - Houses: House 1, House 2, House 3.
#
# Possible red-green combos:
#
# - Red at 1, green at 2
# - Red at 2, green at 3
# - Red at 3 --> green at 4 (impossible)
#
# So red is either house 1 or house 2.
#
# ---
#
# ### Step 2: Assign colors and nationalities
#
# - American is in red house → American lives in red house.
#
# ---
#
# ### Step 3: Assign drinks
#
# - British drinks tea
# - Green house occupant drinks coffee
#
# ---
#
# ### Step 4: Assign pets
#
# - Canadian owns dog
# - Person who owns cat lives next to blue house.
#
# ---
#
# ### Try Red = House 1, Green = House 2:
#
# House 1: Red (American)
# House 2: Green (drinks coffee)
# House 3: Blue
#
# ---
#
# ### Nationalities:
#
# House 1: American (red)
# House 2: ?
# House 3: ?
#
# British drinks tea → British cannot be in green house (drinks coffee), so British must be in house 3 or 1.
#
# - House 1: American
# - House 2: ?
# - House 3: British
#
# Therefore, house 3 is British, drinks tea.
#
# That leaves Canadian in house 2.
#
# ---
#
# ### Pets:
#
# Canadian owns dog → house 2 owns dog.
#
# ---
#
# ### Drinks:
#
# House 1: ?
# House 2: coffee
# House 3: tea
#
# Remaining drink: milk → house 1 drinks milk.
#
# ---
#
# ### Pet of house 1 and 3:
#
# - The cat owner lives next to the blue house.
# - Blue house is house 3.
# - Therefore, cat owner must be in a house next to house 3.
#
# Neighbors of house 3: House 2 only.
#
# House 2 already has dog, so cat can't be in house 2.
#
# Neighbor of blue house alone is house 2.
#
# So house 2 can't have cat (dog), so no cat owner next to blue.
#
# Contradiction.
#
# Therefore, red is not house 1.
#
# ---
#
# ### Step 5: Try Red = House 2, Green = House 3:
#
# House 2: Red (American)
# House 3: Green (drinks coffee)
# House 1: Blue
#
# ---
#
# ### Nationalities:
#
# - American in red house → house 2 American
# - British drinks tea → must be house 1 or house 3
# - Canadian owns dog → the remaining nationality
#
# ---
#
# Assign British and Canadian to houses 1 and 3.
#
# House 3 drinks coffee → occupant is Canadian or British?
#
# British drinks tea, so British can't be green house occupant. Green house occupant drinks coffee → Canadian must be in house 3.
#
# So house 3: Canadian, dog, coffee
#
# House 1: British, tea
#
# ---
#
# ### Drinks:
#
# House 1: tea (British)
# House 2: ?
# House 3: coffee (Canadian)
#
# Remaining drink: milk → house 2 drinks milk
#
# ---
#
# ### Pets:
#
# House 2: ?
#
# House 3: dog
#
# House 1: ?
#
# ---
#
# ### Pet clue:
#
# Person who owns cat lives next to blue house.
#
# Blue house is house 1 (color blue).
#
# Neighbors of house 1 is only house 2.
#
# Cat owner must be house 2.
#
# Therefore:
#
# House 2 owns cat.
#
# ---
#
# ### Summary so far:
#
# | House | Color | Nationality | Drink  | Pet |
# |-------|-------|-------------|--------|-----|
# | 1     | Blue  | British     | Tea    | ?   |
# | 2     | Red   | American    | Milk   | Cat |
# | 3     | Green | Canadian    | Coffee | Dog |
#
# Remaining pet is bird → must belong to house 1.
#
# ---
#
# ### Final answer:
#
# **Who owns the bird?**
#
# The British person in the blue house (house 1) owns the bird.
#
# ---
#
# ## **Answer:**
#
# **The British owns the bird.**

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the problem step-by-step with all the given clues.
#
# ### Entities:
#
# - **Houses:** 3 houses in a row (positions 1, 2, 3)
# - **Colors:** red, blue, green (all different)
# - **Nationalities:** American, British, Canadian (all different)
# - **Pets:** dog, cat, bird (all different)
# - **Drinks:** tea, coffee, milk (all different)
#
# ### Clues:
#
# 1. The American lives in the **red** house.
# 2. The British drinks **tea**.
# 3. The Canadian owns the **dog**.
# 4. The **green** house is immediately to the right of the **red** house.
# 5. The occupant of the **green** house drinks **coffee**.
# 6. The person who owns the **cat** lives next to the **blue** house.
#
# ---
#
# ### Step 1: Setup
#
# Label the houses 1, 2, and 3 from left to right.
#
# We know:
#
# - Green is immediately to the right of red. So if red is in position `x`, green must be in position `x+1`.
# - Houses: House 1, House 2, House 3.
#
# Possible red-green combos:
#
# - Red at 1, green at 2
# - Red at 2, green at 3
# - Red at 3 --> green at 4 (impossible)
#
# So red is either house 1 or house 2.
#
# ---
#
# ### Step 2: Assign colors and nationalities
#
# - American is in red house → American lives in red house.
#
# ---
#
# ### Step 3: Assign drinks
#
# - British drinks tea
# - Green house occupant drinks coffee
#
# ---
#
# ### Step 4: Assign pets
#
# - Canadian owns dog
# - Person who owns cat lives next to blue house.
#
# ---
#
# ### Try Red = House 1, Green = House 2:
#
# House 1: Red (American)
# House 2: Green (drinks coffee)
# House 3: Blue
#
# ---
#
# ### Nationalities:
#
# House 1: American (red)
# House 2: ?
# House 3: ?
#
# British drinks tea → British cannot be in green house (drinks coffee), so British must be in house 3 or 1.
#
# - House 1: American
# - House 2: ?
# - House 3: British
#
# Therefore, house 3 is British, drinks tea.
#
# That leaves Canadian in house 2.
#
# ---
#
# ### Pets:
#
# Canadian owns dog → house 2 owns dog.
#
# ---
#
# ### Drinks:
#
# House 1: ?
# House 2: coffee
# House 3: tea
#
# Remaining drink: milk → house 1 drinks milk.
#
# ---
#
# ### Pet of house 1 and 3:
#
# - The cat owner lives next to the blue house.
# - Blue house is house 3.
# - Therefore, cat owner must be in a house next to house 3.
#
# Neighbors of house 3: House 2 only.
#
# House 2 already has dog, so cat can't be in house 2.
#
# Neighbor of blue house alone is house 2.
#
# So house 2 can't have cat (dog), so no cat owner next to blue.
#
# Contradiction.
#
# Therefore, red is not house 1.
#
# ---
#
# ### Step 5: Try Red = House 2, Green = House 3:
#
# House 2: Red (American)
# House 3: Green (drinks coffee)
# House 1: Blue
#
# ---
#
# ### Nationalities:
#
# - American in red house → house 2 American
# - British drinks tea → must be house 1 or house 3
# - Canadian owns dog → the remaining nationality
#
# ---
#
# Assign British and Canadian to houses 1 and 3.
#
# House 3 drinks coffee → occupant is Canadian or British?
#
# British drinks tea, so British can't be green house occupant. Green house occupant drinks coffee → Canadian must be in house 3.
#
# So house 3: Canadian, dog, coffee
#
# House 1: British, tea
#
# ---
#
# ### Drinks:
#
# House 1: tea (British)
# House 2: ?
# House 3: coffee (Canadian)
#
# Remaining drink: milk → house 2 drinks milk
#
# ---
#
# ### Pets:
#
# House 2: ?
#
# House 3: dog
#
# House 1: ?
#
# ---
#
# ### Pet clue:
#
# Person who owns cat lives next to blue house.
#
# Blue house is house 1 (color blue).
#
# Neighbors of house 1 is only house 2.
#
# Cat owner must be house 2.
#
# Therefore:
#
# House 2 owns cat.
#
# ---
#
# ### Summary so far:
#
# | House | Color | Nationality | Drink  | Pet |
# |-------|-------|-------------|--------|-----|
# | 1     | Blue  | British     | Tea    | ?   |
# | 2     | Red   | American    | Milk   | Cat |
# | 3     | Green | Canadian    | Coffee | Dog |
#
# Remaining pet is bird → must belong to house 1.
#
# ---
#
# ### Final answer:
#
# **Who owns the bird?**
#
# The British person in the blue house (house 1) owns the bird.
#
# ---
#
# ## **Answer:**
#
# **The British owns the bird.**

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages for the first call:

messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic AI opportunity. Respond only with the business area name."}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content
print(f"Business Area: {business_idea}\n")

# Now create a second message including the business idea:
messages.append({"role": "assistant", "content": business_idea})
messages.append({"role": "user", "content": f"Now, focusing on the {business_idea} industry, present a specific pain-point that might be ripe for an Agentic AI solution. Respond with a clear description of the pain-point."})

# Make the second call:
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Extract the pain point:
pain_point = response.choices[0].message.content
print(f"Pain Point: {pain_point}\n")

# Now create a third message for the Agentic AI solution:
messages.append({"role": "assistant", "content": pain_point})
messages.append({"role": "user", "content": f"Based on the business area ({business_idea}) and the pain-point ({pain_point}), propose a specific Agentic AI solution. Describe how the solution would work and why it's well-suited for this problem."})

# Make the third call:
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Display the solution:
solution = response.choices[0].message.content
print(f"Agentic AI Solution:\n{solution}")
# Out:
# Business Area: Supply Chain Management
#
# Pain Point: A significant pain-point in Supply Chain Management is the real-time visibility and proactive disruption handling across complex, multi-tiered supplier networks. Companies often struggle to detect, predict, and respond swiftly to delays, shortages, or quality issues because data is siloed, delayed, or incomplete, leading to costly production stoppages and inefficient inventory management.
#
# Agentic AI Solution:
# Agentic AI Solution: Autonomous Supply Chain Guardian
#
# Description:
# The Autonomous Supply Chain Guardian is an intelligent, agentic AI system designed to continuously monitor, analyze, and manage end-to-end supply chain operations in real time. It integrates data from disparate sources—including supplier databases, logistics trackers, market trends, weather forecasts, geopolitical events, and internal ERP systems—breaking down silos to form a holistic and up-to-date view of the entire multi-tiered supplier network.
#
# How it works:
# 1. **Continuous Data Aggregation & Fusion:** The AI autonomously gathers and harmonizes data from internal and external sources, filling gaps and normalizing inconsistencies through adaptive learning methods.
# 2. **Predictive Disruption Detection:** Using advanced machine learning models and causal inference, it anticipates potential disruptions such as supplier delays, raw material shortages, transportation bottlenecks, or quality issues before they occur.
# 3. **Autonomous Decision-Making & Mitigation:** Upon identifying a risk, the AI evaluates possible mitigation strategies—rerouting shipments, adjusting inventory levels, activating backup suppliers—and autonomously executes approved actions or recommends interventions to human managers with clear reasoning and urgency assessments.
# 4. **Dynamic Feedback Loop:** The system continuously monitors outcomes from its interventions and adapts strategies based on real-world effectiveness, improving over time.
# 5. **Explainability & Collaboration Interface:** Through transparent, natural language explanations and interactive dashboards, the AI collaborates with supply chain teams, enabling trust and efficient human-AI partnership.
#
# Why it's well-suited:
# - **Agentic Autonomy:** By operating proactively without waiting for human commands, the AI can respond swiftly to fast-changing supply chain conditions, reducing reaction times from days/hours to minutes.
# - **Complex Multi-Source Data Handling:** Agentic AI’s ability to autonomously identify data gaps and aggregate from varied, siloed data sets lets it maintain comprehensive visibility that humans and traditional systems struggle to achieve.
# - **Adaptive Learning & Evolution:** The autonomous feedback loop helps the AI improve its predictive and prescriptive power as supply chain dynamics evolve.
# - **Risk Mitigation at Scale:** The system can simultaneously manage a vast supplier network, making decisions tailored to localized events but optimized for global supply chain resilience.
# - **Human-AI Synergy:** Combining autonomous operations with transparent explainability fosters trust and efficient collaboration, ensuring interventions align with strategic business goals.
#
# In summary, the Autonomous Supply Chain Guardian leverages agentic AI’s proactive, adaptive, and autonomous capabilities to transform visibility and disruption management, addressing the critical pain-point by enabling smarter, faster, and more resilient supply chain operations.

# %%
# Display the solution as Markdown

from IPython.display import Markdown, display

display(Markdown(solution))
# Out:
# Agentic AI Solution: Autonomous Supply Chain Guardian
#
# Description:
# The Autonomous Supply Chain Guardian is an intelligent, agentic AI system designed to continuously monitor, analyze, and manage end-to-end supply chain operations in real time. It integrates data from disparate sources—including supplier databases, logistics trackers, market trends, weather forecasts, geopolitical events, and internal ERP systems—breaking down silos to form a holistic and up-to-date view of the entire multi-tiered supplier network.
#
# How it works:
# 1. **Continuous Data Aggregation & Fusion:** The AI autonomously gathers and harmonizes data from internal and external sources, filling gaps and normalizing inconsistencies through adaptive learning methods.
# 2. **Predictive Disruption Detection:** Using advanced machine learning models and causal inference, it anticipates potential disruptions such as supplier delays, raw material shortages, transportation bottlenecks, or quality issues before they occur.
# 3. **Autonomous Decision-Making & Mitigation:** Upon identifying a risk, the AI evaluates possible mitigation strategies—rerouting shipments, adjusting inventory levels, activating backup suppliers—and autonomously executes approved actions or recommends interventions to human managers with clear reasoning and urgency assessments.
# 4. **Dynamic Feedback Loop:** The system continuously monitors outcomes from its interventions and adapts strategies based on real-world effectiveness, improving over time.
# 5. **Explainability & Collaboration Interface:** Through transparent, natural language explanations and interactive dashboards, the AI collaborates with supply chain teams, enabling trust and efficient human-AI partnership.
#
# Why it's well-suited:
# - **Agentic Autonomy:** By operating proactively without waiting for human commands, the AI can respond swiftly to fast-changing supply chain conditions, reducing reaction times from days/hours to minutes.
# - **Complex Multi-Source Data Handling:** Agentic AI’s ability to autonomously identify data gaps and aggregate from varied, siloed data sets lets it maintain comprehensive visibility that humans and traditional systems struggle to achieve.
# - **Adaptive Learning & Evolution:** The autonomous feedback loop helps the AI improve its predictive and prescriptive power as supply chain dynamics evolve.
# - **Risk Mitigation at Scale:** The system can simultaneously manage a vast supplier network, making decisions tailored to localized events but optimized for global supply chain resilience.
# - **Human-AI Synergy:** Combining autonomous operations with transparent explainability fosters trust and efficient collaboration, ensuring interventions align with strategic business goals.
#
# In summary, the Autonomous Supply Chain Guardian leverages agentic AI’s proactive, adaptive, and autonomous capabilities to transform visibility and disruption management, addressing the critical pain-point by enabling smarter, faster, and more resilient supply chain operations.
